# %% [markdown]
# # 02. Cohort Retention & Net Revenue Retention (NRR) Deep Dive
# **Objective**: Analyze month-over-month cohort retention decay matrices and evaluate customer retention health across customer segments.

# %%
import pandas as pd
import numpy as np
import os

data_path = '../data/processed/'
df_cohorts = pd.read_csv(os.path.join(data_path, 'Fact_Monthly_Cohorts.csv'))

# Pivot to create the classic Cohort Heatmap Matrix (Period 0 to 12)
cohort_pivot = df_cohorts.pivot(index='cohort_month', columns='period_number', values='customer_retention_rate_pct')
cohort_pivot.head(10)
